# %% [markdown]
# ## Load JAX, KDExpress, and matplotlib for plotting

# %%
import jax
jax.config.update("jax_enable_x64", True)
jax.config.update("jax_platforms", 'cpu') # put 'gpu' here if you have one
import jax.numpy as jnp
import jax

import os,sys
parent_dir = os.getcwd() + '/../src/'
sys.path.append(parent_dir)
from KDExpress import fft_kde2d, silverman_bw2d, build_hist_edges

import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# %% [markdown]
#  ## Generate random weighted 2-D data

# %%
key = jax.random.PRNGKey(42)
data_2d = jax.random.normal(key, shape=(10_000, 2))
weights = (data_2d[:,0])**2

# Plot
plt.figure(figsize=(7,5))
h = plt.hist2d(
    data_2d[:, 1], data_2d[:, 0], 
    weights=weights, 
    bins=25, 
    density=True, 
    alpha=0.5,
    cmap='plasma' 
)
plt.ylabel("y")
plt.xlabel("x")
viridis = plt.cm.get_cmap('plasma')
proxy_color = viridis(0.5) 
proxy_artist = Patch(facecolor=proxy_color, alpha=0.5, label='Hist. Data')
plt.legend(handles=[proxy_artist])

plt.colorbar(h[3], label='PDF')

plt.show()
# Out:
# /tmp/ipykernel_7663/3431683244.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   viridis = plt.cm.get_cmap('plasma')

# %% [markdown]
# ## Define the points where the PDF is evaluated and compute the bin edges around them and plot the corresponding histogram

# %%
points_x = jnp.linspace(-4, 4, 100)
points_y = jnp.linspace(-4, 4, 100)
px, py = jnp.meshgrid(points_x, points_y, indexing='ij')
bin_edges = [build_hist_edges(points) for points in [points_x, points_y]]
print("Bin edges shape = ", [bin_edges[i].shape for i in range(2)])

plt.figure(figsize=(7,5))
h = plt.hist2d(
  data_2d[:, 1], data_2d[:, 0],  
  weights=weights, 
  bins=bin_edges, 
  density=True, 
  alpha=0.5,
  cmap='plasma'  
)
plt.ylabel("y")
plt.xlabel("x")
viridis = plt.cm.get_cmap('plasma')
proxy_color = viridis(0.5) 
ix = jnp.linspace(0,100,20).astype(int)
scatter_handle = plt.scatter(px[ix,:], py[:,ix], c='red', s=1 , label='(some) Points')
proxy_artist = Patch(facecolor=proxy_color, alpha=0.5, label='Hist. Data')
plt.legend(handles=[proxy_artist, scatter_handle])

plt.colorbar(h[3], label='PDF')

plt.show()
# Out:
# /tmp/ipykernel_7663/3768275069.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   viridis = plt.cm.get_cmap('plasma')
# Bin edges shape =  [(101,), (101,)]

# %% [markdown]
# ## The KDE is computed by convolving the previous "wavy" histogram with a Gaussian kernel. The convolution is (efficiently) performed using an FFT.

# %%
# Calculate optimal bandwidth using Silverman's rule for 2D data (or use custom value)
# Returns bandwidth for each dimension [bw_x, bw_y]
bw = silverman_bw2d(data_2d)  
print("Estimated bandwidths (x, y) = ", bw)

# Compute 2D KDE using FFT-based method
# Note: Reusing bin_edges, though optional
pdf_est_fft = fft_kde2d(
  points_x, 
  points_y, 
  data_2d, 
  weights=weights, 
  bin_edges=bin_edges, 
  bw=bw
)

# Compute JAX KDE 
def jax_scipy_kde2d(x_grid, y_grid, data, weights=None, bw_method=None):
  kde = jax.scipy.stats.gaussian_kde(
    data.T,  
    bw_method=bw_method,
    weights=weights
  )
  X, Y = jnp.meshgrid(x_grid, y_grid, indexing='ij')
  positions = jnp.vstack([X.ravel(), Y.ravel()])
  density = kde(positions).reshape(X.shape)
  return density

pdf_est_jax = jax_scipy_kde2d(
  points_x, 
  points_y, 
  data_2d, 
  weights=weights, 
  bw_method=0.15 # to have comparable bw with FFT Kde
)

# Plot 
fig, (ax1, ax2) = plt.subplots(
  1, 2, 
  figsize=(14, 6), 
  sharex=True, 
  sharey=True,
  constrained_layout=True
)

plot_kwargs = {
  'levels': 25, 
  'cmap': 'plasma',  
  'extend': 'both'  
}


im1 = ax1.contourf(
  points_x, 
  points_y, 
  pdf_est_fft, 
  **plot_kwargs
)
ax1.set_title('FFT KDE', pad=15)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.grid(alpha=0.2)
fig.colorbar(
  im1, 
  ax=ax1, 
  label='PDF',
  fraction=0.046, 
  pad=0.04
)

# Plot JAX KDE results
im2 = ax2.contourf(
  points_x, 
  points_y, 
  pdf_est_jax, 
  **plot_kwargs
)
ax2.set_title("JAX Built-in KDE", pad=15)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.grid(alpha=0.2)
fig.colorbar(
  im2, 
  ax=ax2, 
  label='PDF',
  fraction=0.046,
  pad=0.04
)
plt.show()
# Out:
# Estimated bandwidths (x, y) =  [0.19256654 0.19078095]
